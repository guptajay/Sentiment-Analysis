# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.12.3-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 12.5 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.3.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.4 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 67.1 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 46.5 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 61.0 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.1.2 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.3

# %%
# All the imports!
import tensorflow as tf 
import numpy as np
from tensorflow.keras.preprocessing import sequence
from numpy import array
import random

# Fetch "IMDB Movie Review" data, constraining our reviews to 
# the 10000 most commonly used words
vocab_size = 10000
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=vocab_size)

# Map for readable classnames
class_names = ["Negative", "Positive"]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 1s 0us/step
# 17473536/17464789 [==============================] - 1s 0us/step

# %%
# Get the word index from the dataset
word_index = tf.keras.datasets.imdb.get_word_index()

# Ensure that "special" words are mapped into human readable terms 
word_index = {k:(v+3) for k,v in word_index.items()}
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNKNOWN>"] = 2
word_index["<UNUSED>"] = 3

# Perform reverse word lookup and make it callable
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %%
# Concatonate test and training datasets
allreviews = np.concatenate((x_train, x_test), axis=0)

# Review lengths across test and training whole datasets
print("Maximum review length: {}".format(len(max((allreviews), key=len))))
print("Minimum review length: {}".format(len(min((allreviews), key=len))))
result = [len(x) for x in allreviews]
print("Mean review length: {}".format(np.mean(result)))

# Print a review and it's class as stored in the dataset. Replace the number
# to select a different review.
print("")
print("Machine readable Review")
print("  Review Text: " + str(x_train[60]))
print("  Review Sentiment: " + str(y_train[60]))

# Print a review and it's class in human readable format. Replace the number
# to select a different review.
print("")
print("Human Readable Review")
print("  Review Text: " + decode_review(x_train[60]))
print("  Review Sentiment: " + class_names[y_train[60]])
# Out:
# Maximum review length: 2494
# Minimum review length: 7
# Mean review length: 234.75892
#
# Machine readable Review
#   Review Text: [1, 13, 219, 14, 33, 4, 2, 22, 1413, 12, 16, 373, 175, 2711, 1115, 1026, 430, 939, 16, 23, 2444, 25, 43, 697, 89, 12, 16, 170, 8, 130, 262, 19, 32, 4, 665, 7, 4, 2, 322, 5, 4, 1520, 7, 4, 86, 250, 10, 10, 4, 249, 173, 16, 4, 3891, 6, 19, 4, 167, 564, 5, 564, 1325, 36, 805, 8, 216, 638, 17, 2, 21, 25, 100, 376, 507, 4, 2110, 15, 79, 125, 23, 567, 13, 2134, 233, 36, 4852, 2, 5, 81, 1672, 10, 10, 92, 437, 129, 58, 13, 69, 8, 401, 61, 1432, 39, 1286, 46, 7, 12]
#   Review Sentiment: 0
#
# Human Readable Review
#   Review Text: <START> i saw this at the <UNKNOWN> film festival it was awful every clichéd violent rich boy fantasy was on display you just knew how it was going to end especially with all the shots of the <UNKNOWN> wife and the rape of the first girl br br the worst part was the q a with the director writer and writer producer they tried to come across as <UNKNOWN> but you could tell they're the types that get off on violence i bet anything they frequent <UNKNOWN> and do drugs br br don't waste your time i had to keep my boyfriend from walking out of it
#   Review Sentiment: Negative

# %%
def text_to_encodings(text):
    ar = []
    for i in text:
      if i in word_index:
        ar.append(word_index.get(i, '?'))
    return ar

# %%
x_train_cut = x_train[:1000]
y_train_cut = y_train[:1000]
x_train_list = x_train.tolist()
x_train_cut_list = x_train_cut.tolist()

# %%
from transformers import pipeline

unmasker = pipeline('fill-mask', model='bert-base-cased')
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/416M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
for i in range(20):

    # conert input text from an embedding format to human readable format
    input_text = decode_review(x_train[i])[:200]
    orig_text_list = input_text.split()
    print('input=>', input_text)

    # generate a random integer between 0 and the length of input text
    len_input = len(orig_text_list)
    rand_idx = random.randint(1,len_input-1)

    # replace the word at this random integer with 'MASK'
    new_text_list = orig_text_list.copy()
    new_text_list[rand_idx] = '[MASK]'
    new_mask_sent = ' '.join(new_text_list)
    print('masked->', new_mask_sent)

    # replace the masked word with another word suiting the context of the sentence
    augmented_text_list = unmasker(new_mask_sent)

    # check if the new word is not the same as the original word
    for res in augmented_text_list:
      if res['token_str'] != orig_text_list[rand_idx]:
        augmented_text = res['sequence']
        break
    print("Augmented text->",augmented_text)

    # add augmented data with label to our original train data points
    ar = text_to_encodings(augmented_text)
    x_train_cut_list.append(ar)
    y_train_cut = np.append(y_train_cut, y_train_cut[i])
# Out:
# input=> <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNKNOWN> is an amazing actor
# masked-> <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there [MASK] <UNKNOWN> is an amazing actor
# Augmented text-> < START > this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there. < UNKNOWN > is an amazing actor
# input=> <START> big hair big boobs bad music and a giant safety pin these are the words to best describe this terrible movie i love cheesy horror movies and i've seen hundreds but this had got to be on of the
# masked-> <START> big hair big boobs bad music and a giant [MASK] pin these are the words to best describe this terrible movie i love cheesy horror movies and i've seen hundreds but this had got to be on of the
# Augmented text-> < START > big hair big boobs bad music and a giant hair pin these are the words to best describe this terrible movie i love cheesy horror movies and i've seen hundreds but this had got to be on of the
# input=> <START> this has to be one of the worst films of the 1990s when my friends i were watching this film being the target audience it was aimed at we just sat watched the first half an hour with our jaws
# masked-> <START> this has to be one of the worst films of the 1990s when my friends i were watching this film being the target audience it was aimed at we [MASK] sat watched the first half an hour with our jaws
# Augmented text-> < START > this has to be one of the worst films of the 1990s when my friends i were watching this film being the target audience it was aimed at we both sat watched the first half an hour with our jaws
# input=> <START> the <UNKNOWN> <UNKNOWN> at storytelling the traditional sort many years after the event i can still see in my <UNKNOWN> eye an elderly lady my friend's mother retelling the battle of <UNKNOWN>
# masked-> <START> the <UNKNOWN> <UNKNOWN> at storytelling the [MASK] sort many years after the event i can still see in my <UNKNOWN> eye an elderly lady my friend's mother retelling the battle of <UNKNOWN>
# Augmented text-> < START > the < UNKNOWN > < UNKNOWN > at storytelling the same sort many years after the event i can still see in my < UNKNOWN > eye an elderly lady my friend's mother retelling the battle of < UNKNOWN >
# input=> <START> worst mistake of my life br br i picked this movie up at target for 5 because i figured hey it's sandler i can get some cheap laughs i was wrong completely wrong mid way through the film all t
# masked-> <START> worst mistake of [MASK] life br br i picked this movie up at target for 5 because i figured hey it's sandler i can get some cheap laughs i was wrong completely wrong mid way through the film all t
# Augmented text-> < START > worst mistake of your life br br i picked this movie up at target for 5 because i figured hey it's sandler i can get some cheap laughs i was wrong completely wrong mid way through the film all t
# input=> <START> begins better than it ends funny that the russian submarine crew <UNKNOWN> all other actors it's like those scenes where documentary shots br br spoiler part the message <UNKNOWN> was contrary
# masked-> <START> begins better than it ends funny that the russian submarine crew <UNKNOWN> all other actors it's like those scenes where documentary shots br br spoiler part the message <UNKNOWN> was [MASK]
# Augmented text-> < START > begins better than it ends funny that the russian submarine crew < UNKNOWN > all other actors it's like those scenes where documentary shots br br spoiler part the message < UNKNOWN > was.
# input=> <START> lavish production values and solid performances in this straightforward adaption of jane <UNKNOWN> satirical classic about the marriage game within and between the classes in <UNKNOWN> 18th ce
# masked-> <START> lavish production values and solid performances in this straightforward adaption of jane [MASK] satirical classic about the marriage game within and between the classes in <UNKNOWN> 18th ce
# Augmented text-> < START > lavish production values and solid performances in this straightforward adaption of janety satirical classic about the marriage game within and between the classes in < UNKNOWN > 18th ce
# input=> <START> the <UNKNOWN> tells the story of the four hamilton siblings teenager francis <UNKNOWN> <UNKNOWN> twins <UNKNOWN> joseph <UNKNOWN> <UNKNOWN> <UNKNOWN> <UNKNOWN> the <UNKNOWN> david samuel who i
# masked-> <START> the <UNKNOWN> tells [MASK] story of the four hamilton siblings teenager francis <UNKNOWN> <UNKNOWN> twins <UNKNOWN> joseph <UNKNOWN> <UNKNOWN> <UNKNOWN> <UNKNOWN> the <UNKNOWN> david samuel who i
# Augmented text-> < START > the < UNKNOWN > tells a story of the four hamilton siblings teenager francis < UNKNOWN > < UNKNOWN > twins < UNKNOWN > joseph < UNKNOWN > < UNKNOWN > < UNKNOWN > < UNKNOWN > the < UNKNOWN > david samuel who i
# input=> <START> just got out and cannot believe what a brilliant documentary this is rarely do you walk out of a movie theater in such awe and <UNKNOWN> lately movies have become so over hyped that the thrill
# masked-> <START> just got out and cannot believe what a brilliant documentary this is rarely do you walk out of a movie theater in such awe and [MASK] lately movies have become so over hyped that the thrill
# Augmented text-> < START > just got out and cannot believe what a brilliant documentary this is rarely do you walk out of a movie theater in such awe and that lately movies have become so over hyped that the thrill
# input=> <START> this movie has many problem associated with it that makes it come off like a low budget class project from someone in film school i have to give it credit on its <UNKNOWN> though many times th
# masked-> <START> this movie has many problem associated with it [MASK] makes it come off like a low budget class project from someone in film school i have to give it credit on its <UNKNOWN> though many times th
# Augmented text-> < START > this movie has many problem associated with it which makes it come off like a low budget class project from someone in film school i have to give it credit on its < UNKNOWN > though many times th
# input=> <START> french horror cinema has seen something of a revival over the last couple of years with great films such as inside and <UNKNOWN> romance <UNKNOWN> on to the scene <UNKNOWN> <UNKNOWN> the reviv
# masked-> <START> french horror cinema has seen something of a revival over the last couple of years with great films such as inside and <UNKNOWN> romance <UNKNOWN> on [MASK] the scene <UNKNOWN> <UNKNOWN> the reviv
# Augmented text-> < START > french horror cinema has seen something of a revival over the last couple of years with great films such as inside and < UNKNOWN > romance < UNKNOWN > on - the scene < UNKNOWN > < UNKNOWN > the reviv
# input=> <START> when i rented this movie i had very low expectations but when i saw it i realized that the movie was less a lot less than what i expected the actors were bad the doctor's wife was one of the w
# masked-> <START> when i [MASK] this movie i had very low expectations but when i saw it i realized that the movie was less a lot less than what i expected the actors were bad the doctor's wife was one of the w
# Augmented text-> < START > when i saw this movie i had very low expectations but when i saw it i realized that the movie was less a lot less than what i expected the actors were bad the doctor's wife was one of the w
# input=> <START> i love cheesy horror flicks i don't care if the acting is sub par or whether the monsters look corny i liked this movie except for the <UNKNOWN> feeling all the way from the beginning of the f
# masked-> <START> i love cheesy horror flicks i don't care if the acting is sub par or [MASK] the monsters look corny i liked this movie except for the <UNKNOWN> feeling all the way from the beginning of the f
# Augmented text-> < START > i love cheesy horror flicks i don't care if the acting is sub par or if the monsters look corny i liked this movie except for the < UNKNOWN > feeling all the way from the beginning of the f
# input=> <START> anyone who could find redeeming value in this piece of crap ought to have their head examined we have the <UNKNOWN> heroin addicted part time hooker wife with <UNKNOWN> all over her body <UNKN
# masked-> <START> anyone who could find redeeming value in this piece of crap ought to have their head examined we have the <UNKNOWN> [MASK] addicted part time hooker wife with <UNKNOWN> all over her body <UNKN
# Augmented text-> < START > anyone who could find redeeming value in this piece of crap ought to have their head examined we have the < UNKNOWN > drug addicted part time hooker wife with < UNKNOWN > all over her body < UNKN
# input=> <START> b movie at best sound effects are pretty good lame concept decent execution i suppose it's a rental br br you put some <UNKNOWN> oil in your mouth to save you from de poison <UNKNOWN> you cut
# masked-> <START> b movie at best sound effects are pretty good lame concept decent execution i suppose it's a rental br br you put some <UNKNOWN> oil in your mouth to save [MASK] from de poison <UNKNOWN> you cut
# Augmented text-> < START > b movie at best sound effects are pretty good lame concept decent execution i suppose it's a rental br br you put some < UNKNOWN > oil in your mouth to save it from de poison < UNKNOWN > you cut
# input=> <START> a total waste of time just throw in a few explosions non stop fighting exotic cars a deranged millionaire slow motion computer generated car crashes and last but not least a hugh <UNKNOWN> lik
# masked-> <START> a total waste of time just throw in a few explosions non stop fighting exotic cars a deranged millionaire slow motion computer generated car crashes and last but [MASK] least a hugh <UNKNOWN> lik
# Augmented text-> < START > a total waste of time just throw in a few explosions non stop fighting exotic cars a deranged millionaire slow motion computer generated car crashes and last but never least a hugh < UNKNOWN > lik
# input=> <START> laputa castle in the sky is the bomb the message is as strong as his newer works and more pure fantastic and flying pirates how could it be any better the art is totally amazing and the soundt
# masked-> <START> laputa castle in the sky is [MASK] bomb the message is as strong as his newer works and more pure fantastic and flying pirates how could it be any better the art is totally amazing and the soundt
# Augmented text-> < START > laputa castle in the sky is a bomb the message is as strong as his newer works and more pure fantastic and flying pirates how could it be any better the art is totally amazing and the soundt
# input=> <START> at the height of the <UNKNOWN> big <UNKNOWN> racism row in 2007 involving <UNKNOWN> <UNKNOWN> and the late <UNKNOWN> <UNKNOWN> i condemned on an internet forum those <UNKNOWN> b b ' fans who p
# masked-> <START> at [MASK] height of the <UNKNOWN> big <UNKNOWN> racism row in 2007 involving <UNKNOWN> <UNKNOWN> and the late <UNKNOWN> <UNKNOWN> i condemned on an internet forum those <UNKNOWN> b b ' fans who p
# Augmented text-> < START > at a height of the < UNKNOWN > big < UNKNOWN > racism row in 2007 involving < UNKNOWN > < UNKNOWN > and the late < UNKNOWN > < UNKNOWN > i condemned on an internet forum those < UNKNOWN > b b'fans who p
# input=> <START> i have only had the luxury of seeing this movie once when i was rather young so much of the movie is <UNKNOWN> in trying to remember it however i can say it was not as funny as a movie called
# masked-> <START> i have only had the luxury of seeing this movie [MASK] when i was rather young so much of the movie is <UNKNOWN> in trying to remember it however i can say it was not as funny as a movie called
# Augmented text-> < START > i have only had the luxury of seeing this movie before when i was rather young so much of the movie is < UNKNOWN > in trying to remember it however i can say it was not as funny as a movie called
# input=> <START> chances are is a charming romantic fantasy about a woman <UNKNOWN> shepherd whose husband christopher <UNKNOWN> is killed shortly after learning she is pregnant we then see the husband in heav
# masked-> <START> chances are is a charming romantic fantasy about a woman <UNKNOWN> shepherd whose husband christopher <UNKNOWN> is killed shortly after learning she is pregnant we then see the husband [MASK] heav
# Augmented text-> < START > chances are is a charming romantic fantasy about a woman < UNKNOWN > shepherd whose husband christopher < UNKNOWN > is killed shortly after learning she is pregnant we then see the husband - heav

# %%
x_train_cut = np.array(x_train_cut_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Pre-processing Data
#
# We need to make sure that our reviews are of a uniform length. This is for the LSTM's parameters.
#
# Some reviews will need to be truncated, while others need to be padded.

# %%
# The length of reviews
review_length = 500

# Padding / truncated our reviews
x_train_cut = sequence.pad_sequences(x_train_cut, maxlen = review_length)
x_test = sequence.pad_sequences(x_test, maxlen = review_length)

# Check the size of our datasets. Review data for both test and training should 
# contain 25000 reviews of 500 integers. Class data should contain 25000 values, 
# one for each review. Class values are 0 or 1, indicating a negative 
# or positive review.
print("Shape Training Review Data: " + str(x_train_cut.shape))
print("Shape Training Class Data: " + str(y_train_cut.shape))
print("Shape Test Review Data: " + str(x_test.shape))
print("Shape Test Class Data: " + str(y_test.shape))

# Note padding is added to start of review, not the end
print("")
print("Human Readable Review Text (post padding): " + decode_review(x_train_cut[60]))
# Out:
# Shape Training Review Data: (1020, 500)
# Shape Training Class Data: (1020,)
# Shape Test Review Data: (25000, 500)
# Shape Test Class Data: (25000,)
#
# Human Readable Review Text (post padding): <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <START> i saw this at the <UNKNOWN> film festival it was awful every clichéd violent rich boy fantasy was on display you just knew how it was going to end especially with all the shots of the <UNKNOWN> wife and the rape of the first girl br br the worst part was the q a with the director writer and writer producer they tried to come across as <UNKNOWN> but you could tell they're the types that get off on violence i bet anything they frequent <UNKNOWN> and do drugs br br don't waste your time i had to keep my boyfriend from walking out of it

# %% [markdown]
# ## Create and build LSTM Recurrent Neural Network

# %%
# We begin by defining the a empty stack. We'll use this for building our 
# network, later by layer.
model = tf.keras.models.Sequential()

# The Embedding Layer provides a spatial mapping (or Word Embedding) of all the 
# individual words in our training set. Words close to one another share context 
# and or meaning. This spatial mapping is learning during the training process.
model.add(
    tf.keras.layers.Embedding(
        input_dim = vocab_size, # The size of our vocabulary 
        output_dim = 32, # Dimensions to which each words shall be mapped
        input_length = review_length # Length of input sequences
    )
)

# Dropout layers fight overfitting and forces the model to learn multiple 
# representations of the same data by randomly disabling neurons in the 
# learning phase.
model.add(
    tf.keras.layers.Dropout(
        rate=0.25 # Randomly disable 25% of neurons
    )
)

# x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
# x = layers.Bidirectional(layers.LSTM(64))(x)

# We are using a fast version of LSTM whih is optimised for GPUs. This layer 
# looks at the sequence of words in the review, along with their word embeddings
# and uses both of these to determine to sentiment of a given review.
model.add(
    tf.keras.layers.GRU(
        units=32 # 32 LSTM units in this layer
    )
)

# model.add(
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True))
# )

# model.add(
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64))
# )

# Add a second dropout layer with the same aim as the first.
model.add(
    tf.keras.layers.Dropout(
        rate=0.25 # Randomly disable 25% of neurons
    )
)

# All LSTM units are connected to a single node in the dense layer. A sigmoid 
# activation function determines the output from this node - a value 
# between 0 and 1. Closer to 0 indicates a negative review. Closer to 1 
# indicates a positive review.
model.add(
    tf.keras.layers.Dense(
        units=1, # Single unit
        activation='sigmoid' # Sigmoid activation function (output from 0 to 1)
    )
)

# Compile the model
model.compile(
    loss=tf.keras.losses.binary_crossentropy, # loss function
    optimizer=tf.keras.optimizers.Adam(), # optimiser function
    metrics=['accuracy']) # reporting metric

# Display a summary of the models structure
model.summary()

# %% [markdown]
# ## Visualise the Model

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False)

# %% [markdown]
# ## Train the LSTM

# %%
# Train the LSTM on the training data
history = model.fit(

    # Training data : features (review) and classes (positive or negative)
    x_train_cut, y_train_cut,
                    
    # Number of samples to work through before updating the 
    # internal model parameters via back propagation. The 
    # higher the batch, the more memory you need.
    batch_size=32, 

    # An epoch is an iteration over the entire training data.
    epochs=3, 
    
    # The model will set apart his fraction of the training 
    # data, will not train on it, and will evaluate the loss
    # and any model metrics on this data at the end of 
    # each epoch.
    validation_split=0.2,
    
    verbose=1
)

# %% [markdown]
# ## Evaluate model with test data and view results

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
scores[1]

# for 500 points, acc = 55.32
# for 100 points, acc = 72.89
